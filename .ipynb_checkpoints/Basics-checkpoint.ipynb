# %% [markdown]
# # Dataquest.io Guided Project One
#
# ### In this notebook, data cleaning and exploration techniques are practiced. Specifically, locating and deleting duplicate data are a focus.

# %% [markdown]
# #### explore_data() function takes a dataset in the form of a list of lists, and prints out a selection of that dataset given starting and ending points as parameters. Optionally, it can print out the row and column numbers.

# %%
def explore_data(dataset, start, end, rows_and_columns=False):
    dataset_slice = dataset[start:end]
    for row in dataset_slice:
        print(row)
        print('\n')

    if rows_and_columns:
        print('Number of rows: ', len(dataset))
        print('Number of column: ', len(dataset[0]))

# %% [markdown]
# #### Import reader from csc. Open and read AppleStore.csv and googleplaystore.csv. Convert those csv files to lists of lists named apple_data and google_data, respectively.

# %%
from csv import reader
apple_open = open('AppleStore.csv')
google_open = open('googleplaystore.csv')
apple_read = reader(apple_open)
google_read = reader(google_open)
apple_data = list(apple_read)
google_data = list(google_read)

# %% [markdown]
# #### Take a look at the apple_data by calling explore_data().

# %%
explore_data(apple_data, 0, len(apple_data[0])-1, True)
# Out:
# ['id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']
#
#
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']
#
#
# ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1']
#
#
# ['420009108', 'Temple Run', '65921024', 'USD', '0.0', '1724546', '3842', '4.5', '4.0', '1.6.2', '9+', 'Games', '40', '5', '1', '1']
#
#
# ['284035177', 'Pandora - Music & Radio', '130242560', 'USD', '0.0', '1126879', '3594', '4.0', '4.5', '8.4.1', '12+', 'Music', '37', '4', '1', '1']
#
#
# ['429047995', 'Pinterest', '74778624', 'USD', '0.0', '1061624', '1814', '4.5', '4.0', '6.26', '12+', 'Social Networking', '37', '5', '27', '1']
#
#
# ['282935706', 'Bible', '92774400', 'USD', '0.0', '985920', '5320', '4.5', '5.0', '7.5.1', '4+', 'Reference', '37', '5', '45', '1']
#
#
# ['553834731', 'Candy Crush Saga', '222846976', 'USD', '0.0', '961794', '2453', '4.5', '4.5', '1.101.0', '4+', 'Games', '43', '5', '24', '1']
#
#
# ['324684580', 'Spotify Music', '132510720', 'USD', '0.0', '878563', '8253', '4.5', '4.5', '8.4.3', '12+', 'Music', '37', '5', '18', '1']
#
#
# ['343200656', 'Angry Birds', '175966208', 'USD', '0.0', '824451', '107', '4.5', '3.0', '7.4.0', '4+', 'Games', '38', '0', '10', '1']
#
#
# ['512939461', 'Subway Surfers', '156038144', 'USD', '0.0', '706110', '97', '4.5', '4.0', '1.72.1', '9+', 'Games', '38', '5', '1', '1']
#
#
# ['362949845', 'Fruit Ninja Classic', '104590336', 'USD', '1.99', '698516', '132', '4.5', '4.0', '2.3.9', '4+', 'Games', '38', '5', '13', '1']
#
#
# ['359917414', 'Solitaire', '101943296', 'USD', '0.0', '679055', '9673', '4.5', '4.5', '4.11.2', '4+', 'Games', '38', '4', '11', '1']
#
#
# ['469369175', 'CSR Racing', '524803072', 'USD', '0.0', '677247', '2029', '4.5', '4.5', '4.0.1', '4+', 'Games', '37', '5', '10', '1']
#
#
# Number of rows:  7198
# Number of column:  16

# %% [markdown]
# #### Let's take a look at the google_data by calling explore_data().

# %%
explore_data(google_data, 0, len(google_data[0]), True)
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
#
#
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['Coloring book moana', 'ART_AND_DESIGN', '3.9', '967', '14M', '500,000+', 'Free', '0', 'Everyone', 'Art & Design;Pretend Play', 'January 15, 2018', '2.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# ['Pixel Draw - Number Art Coloring Book', 'ART_AND_DESIGN', '4.3', '967', '2.8M', '100,000+', 'Free', '0', 'Everyone', 'Art & Design;Creativity', 'June 20, 2018', '1.1', '4.4 and up']
#
#
# ['Paper flowers instructions', 'ART_AND_DESIGN', '4.4', '167', '5.6M', '50,000+', 'Free', '0', 'Everyone', 'Art & Design', 'March 26, 2017', '1.0', '2.3 and up']
#
#
# ['Smoke Effect Photo Maker - Smoke Editor', 'ART_AND_DESIGN', '3.8', '178', '19M', '50,000+', 'Free', '0', 'Everyone', 'Art & Design', 'April 26, 2018', '1.1', '4.0.3 and up']
#
#
# ['Infinite Painter', 'ART_AND_DESIGN', '4.1', '36815', '29M', '1,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'June 14, 2018', '6.1.61.1', '4.2 and up']
#
#
# ['Garden Coloring Book', 'ART_AND_DESIGN', '4.4', '13791', '33M', '1,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'September 20, 2017', '2.9.2', '3.0 and up']
#
#
# ['Kids Paint Free - Drawing Fun', 'ART_AND_DESIGN', '4.7', '121', '3.1M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design;Creativity', 'July 3, 2018', '2.8', '4.0.3 and up']
#
#
# ['Text on Photo - Fonteee', 'ART_AND_DESIGN', '4.4', '13880', '28M', '1,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'October 27, 2017', '1.0.4', '4.1 and up']
#
#
# ['Name Art Photo Editor - Focus n Filters', 'ART_AND_DESIGN', '4.4', '8788', '12M', '1,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'July 31, 2018', '1.0.15', '4.0 and up']
#
#
# Number of rows:  10842
# Number of column:  13

# %% [markdown]
# #### So, from the print out above, there are 13 columns in the google_data set. The  cell below prints out any list in that data set that is not 13 columns wide, in an effort to find missing data. The idea is that within the list of lists, if there is a list that is not the same length as the header, than it is either missing data, or it has additional data.

# %%
for row in google_data:
    header_length = len(google_data[0])
    if len(row) != header_length:
        print(row)
        print(google_data.index(row))
        
# Save the header for posterity
google_head = google_data[0]
# Out:
# ['Life Made WI-Fi Touchscreen Photo Frame', '1.9', '19', '3.0M', '1,000+', 'Free', '0', 'Everyone', '', 'February 11, 2018', '1.0.19', '4.0 and up']
# 10473

# %% [markdown]
# #### One such row exists. It is deleted below.

# %%
del google_data[10473]

# %% [markdown]
# #### This cell creates 3 new lists:
# #### g_dup_apps contains the names of the apps that have duplicate entries in google_data;
# #### g_dup_index contains the index location of the duplicate entry in google_data;
# #### g_unique_apps contains the names of the apps that do not have duplicate entries in google_data

# %%
# Create two lists: 1 for unique and 1 for duplicate apps; the list for duplicate apps
# should not have duplicates itself; otherwise, care would have to be taken to make
# sure that 1 row in the dataset with a name in the duplicates list is kept; IE: we do
# not want to remove all the rows that are duplicates; we want to keep 1
g_dup_apps = []
g_unique_apps = []

for row in google_data:
    name = row[0]
    # This if clause keeps duplicates from occurring in the duplicates list
    if name in g_unique_apps and name in g_dup_apps: continue
    elif name not in g_unique_apps: g_unique_apps.append(name)
    elif name in g_unique_apps and name not in g_dup_apps: g_dup_apps.append(name)

print('Number of google apps that have duplicates: ', len(g_dup_apps))
print('\n')
print('Print first 10 duplicates:\n', g_dup_apps[:10])
# Out:
# Number of google apps that have duplicates:  798
#
#
# Print first 10 duplicates:
#  ['Quick PDF Scanner + OCR FREE', 'Box', 'Google My Business', 'ZOOM Cloud Meetings', 'join.me - Simple Meetings', 'Zenefits', 'Google Ads', 'Slack', 'FreshBooks Classic', 'Insightly CRM']

# %% [markdown]
# #### The apps with the highest number of downloads are kept in google_data set. All others are deleted.

# %%
# remove_dups()
# Function takes in the name of an app w/ duplicates, a dataset, a list, and a
# column number as parameters. It creates a list of the row numbers to be deleted.
# These rows are sorted from least to greatest values of the column number that is
# passed as an argument. The row with the greatest of those values is not deleted. 
def remove_dups(an_app, a_dataset, a_col):

    # Iterate through a_dataset; if the app name matches the one passed as an argument,
    # append its index number to the row, and append the row to dup_list
    dup_list = []
    for i in range(0, len(a_dataset)):
        row = a_dataset[i]
        if row[0] == an_app:
            row.append(i)
            dup_list.append(row)

    # Sort dup_list from greatest to least value in position a_col; delete the row with
    # the greatest value from dup_list
    dup_list.sort(key=lambda x: x[a_col], reverse=True)
    del dup_list[0]

    # Iterate through dup_list; delete each row in a_dataset that corresponds to the index
    # appended to each list in dup_list
    j = 0
    while j < len(dup_list):
        del a_dataset[j]
        j += 1

    return(a_dataset)

# %%
# Call remove_dups() on google duplicates
for app in g_dup_apps:
    remove_dups(app, google_data, 3)   

# Check number rows of google_data
print(len(google_data))
# Out:
# 9717

# %%
for row in apple_data:
    header_length = len(apple_data[0])
    if len(row) != header_length:
        print(row)
        print(apple_data.index(row))
        
# Save the header for posterity
apple_head = apple_data[0]

# %% [markdown]
# #### There are no rows that are not the same length as the header in the apple data

# %%
a_dup_apps = []
a_unique_apps = []

for row in apple_data:
    name = row[0]
    if name in a_unique_apps:
        if name in a_dup_apps: continue
        else:
            a_dup_apps.append(name)
    else: a_unique_apps.append(name)

print('Number of duplicate apple apps: ', len(a_dup_apps))
print('\n')
print('Print first 10 duplicates:\n', a_dup_apps[:10])
# Out:
# Number of duplicate apple apps:  0
#
#
# Print first 10 duplicates:
#  []

# %% [markdown]
# #### There are no duplicate apps in the apple data

# %%
# remove_non_eng()
# This function take in a string and returns False if there are non-english characters
# in it; otherwise, it returns True; if the ASCII is greater than 127, then it is
# non-english; no return means that all characters in the string are english
def bool_non_eng(a_string):
    count = 0
    for char in a_string:
        if ord(char) > 127: count += 1
    if count > 3: return False
    else: return True

# %%
# Test remove_non_eng()
print(bool_non_eng('Instagram'))                        # True
print(bool_non_eng('爱奇艺PPS -《欢乐颂2》电视剧热播'))      # False
print(bool_non_eng('Docs To Go™ Free Office Suite'))   # True
print(bool_non_eng('Instachat 😜'))                    # True
# Out:
# True
# False
# True
# True

# %%
# Call bool_non_eng() on google_data; create list of rows w/ non-english app names;
# append row indices to data to be removed
g_non_eng = []
for row in google_data:
    if bool_non_eng(row[0]) == False:
        row.append(google_data.index(row))
        g_non_eng.append(row)
        
print(len(g_non_eng))
print(g_non_eng[:3])

# 44 non-english app names in google_data
# Out:
# 44
# [['သိင်္ Astrology - Min Thein Kha BayDin', 'LIFESTYLE', '4.7', '2225', '15M', '100,000+', 'Free', '0', 'Everyone', 'Lifestyle', 'July 26, 2018', '4.2.1', '4.0.3 and up', 469], ['РИА Новости', 'NEWS_AND_MAGAZINES', '4.5', '44274', '8.0M', '1,000,000+', 'Free', '0', 'Everyone', 'News & Magazines', 'August 6, 2018', '4.0.6', '4.4 and up', 2627], ['صور حرف H', 'ART_AND_DESIGN', '4.4', '13', '4.5M', '1,000+', 'Free', '0', 'Everyone', 'Art & Design', 'March 27, 2018', '2.0', '4.0.3 and up', 3070]]

# %%
# Delete all 44 rows with non-english app names from google_data
for row in g_non_eng:
    index = row[len(row)-1]
    del google_data[index]

# Expect 9,673 rows left
print(len(google_data))
# Out:
# 9673

# %%
# Call bool_non_eng() on apple_data; create list of rows w/ non-english app names
a_non_eng = []
for row in apple_data:
    if bool_non_eng(row[0]) == False: a_non_eng.append(row)
print(len(a_non_eng))

# No non-english app names in apple_data
# Out:
# 0

# %%
# Take a look at the cleaned google dataset
explore_data(google_data, 0, 15, True)

# Apple dataset has not changed
# Out:
# ['QuickBooks Self-Employed:Mileage Tracker and Taxes', 'FINANCE', '4.4', '15141', '25M', '1,000,000+', 'Free', '0', 'Everyone', 'Finance', 'July 24, 2018', '4.63', '5.0 and up']
#
#
# ['FREE Stock Market Trading Tips', 'FINANCE', '3.9', '714', '3.6M', '50,000+', 'Free', '0', 'Everyone', 'Finance', 'June 7, 2017', '2.10.3', '2.3.3 and up']
#
#
# ['MetaTrader 5', 'FINANCE', '4.5', '42410', 'Varies with device', '1,000,000+', 'Free', '0', 'Everyone', 'Finance', 'August 3, 2018', 'Varies with device', 'Varies with device']
#
#
# ['MetaTrader 4', 'FINANCE', '4.6', '260547', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Finance', 'July 31, 2018', 'Varies with device', 'Varies with device']
#
#
# ['Stock Quote', 'FINANCE', '4.1', '4344', '4.5M', '500,000+', 'Free', '0', 'Everyone', 'Finance', 'July 30, 2018', '3.6.2', '4.0 and up']
#
#
# ['Seeking Alpha', 'FINANCE', '4.5', '22808', 'Varies with device', '1,000,000+', 'Free', '0', 'Everyone', 'Finance', 'August 3, 2018', 'Varies with device', 'Varies with device']
#
#
# ['Stock Trainer: Virtual Trading (Stock Markets)', 'FINANCE', '4.4', '42809', '23M', '1,000,000+', 'Free', '0', 'Everyone', 'Finance', 'July 27, 2018', '3.04 - Beta', '4.1 and up']
#
#
# ['Stocks: Realtime Quotes Charts', 'FINANCE', '4.5', '16808', 'Varies with device', '1,000,000+', 'Free', '0', 'Everyone', 'Finance', 'May 1, 2018', 'Varies with device', 'Varies with device']
#
#
# ['Stocks, Forex, Bitcoin, Ethereum: Portfolio & News', 'FINANCE', '4.6', '157505', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Finance', 'August 1, 2018', 'Varies with device', 'Varies with device']
#
#
# ['CNBC: Breaking Business News & Live Market Data', 'FINANCE', '4.2', '24647', 'Varies with device', '1,000,000+', 'Free', '0', 'Everyone', 'Finance', 'July 13, 2018', 'Varies with device', 'Varies with device', 30]
#
#
# ['US Stock Market', 'FINANCE', '4.4', '1922', '4.2M', '100,000+', 'Free', '0', 'Everyone', 'Finance', 'August 1, 2018', '1.28', '2.3 and up']
#
#
# ['Bloomberg Professional', 'FINANCE', '4.1', '3334', 'Varies with device', '500,000+', 'Free', '0', 'Everyone', 'Finance', 'July 23, 2018', 'Varies with device', 'Varies with device']
#
#
# ['E*TRADE Mobile', 'FINANCE', '3.9', '10658', '58M', '1,000,000+', 'Free', '0', 'Everyone', 'Finance', 'August 2, 2018', '6.8.2', '4.4 and up', 195]
#
#
# ['Robinhood - Investing, No Fees', 'FINANCE', '4.6', '57493', 'Varies with device', '1,000,000+', 'Free', '0', 'Everyone', 'Finance', 'July 31, 2018', 'Varies with device', 'Varies with device', 877]
#
#
# ['MSN Money- Stock Quotes & News', 'FINANCE', '4.5', '78361', '22M', '1,000,000+', 'Free', '0', 'Everyone', 'Finance', 'July 5, 2018', '1.2.0', '4.2 and up']
#
#
# Number of rows:  9673
# Number of column:  13

# %% [markdown]
# #### We only build apps that are free to download and install. So, our main source of revenue is from in-app ads. From here, we need to isolate the free apps from our data sets.

# %%
# The element that indicates whether an app is free or not is element #6 in the google_data; and, the value
# of 'Free' indicates this.
g_free = []
for row in google_data:
    if row[6] == 'Free': g_free.append(row)
        
print(g_free[:5])
print("\n")
print(g_free[500:510])
print("\n")
print("Number of free apps in Google Play Store: ", len(g_free))
# Out:
# [['QuickBooks Self-Employed:Mileage Tracker and Taxes', 'FINANCE', '4.4', '15141', '25M', '1,000,000+', 'Free', '0', 'Everyone', 'Finance', 'July 24, 2018', '4.63', '5.0 and up'], ['FREE Stock Market Trading Tips', 'FINANCE', '3.9', '714', '3.6M', '50,000+', 'Free', '0', 'Everyone', 'Finance', 'June 7, 2017', '2.10.3', '2.3.3 and up'], ['MetaTrader 5', 'FINANCE', '4.5', '42410', 'Varies with device', '1,000,000+', 'Free', '0', 'Everyone', 'Finance', 'August 3, 2018', 'Varies with device', 'Varies with device'], ['MetaTrader 4', 'FINANCE', '4.6', '260547', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Finance', 'July 31, 2018', 'Varies with device', 'Varies with device'], ['Stock Quote', 'FINANCE', '4.1', '4344', '4.5M', '500,000+', 'Free', '0', 'Everyone', 'Finance', 'July 30, 2018', '3.6.2', '4.0 and up']]
#
#
# [['Chictopia', 'LIFESTYLE', '4.1', '360', '4.6M', '10,000+', 'Free', '0', 'Everyone', 'Lifestyle', 'April 30, 2014', '1.6.2', '2.2 and up', 1287], ['Scarf Fashion Designer', 'LIFESTYLE', '4.4', '16637', '10M', '1,000,000+', 'Free', '0', 'Everyone', 'Lifestyle', 'June 18, 2017', '1.8', '2.3 and up', 1287], ['Fashion in Vogue', 'LIFESTYLE', '3.8', '1797', '6.8M', '100,000+', 'Free', '0', 'Everyone', 'Lifestyle', 'September 27, 2016', '2.0', '4.3 and up', 1293], ['Zara', 'LIFESTYLE', '4.3', '95905', '33M', '10,000,000+', 'Free', '0', 'Everyone', 'Lifestyle', 'July 30, 2018', '4.1.0', '4.1 and up', 1288], ['Real Estate by Movoto', 'LIFESTYLE', '4.4', '3114', '13M', '100,000+', 'Free', '0', 'Everyone', 'Lifestyle', 'February 20, 2018', '6.1', '4.0.3 and up'], ['Etta Homes', 'LIFESTYLE', '4.2', '220', '15M', '50,000+', 'Free', '0', 'Everyone', 'Lifestyle', 'July 26, 2018', '9.1.0', '5.0 and up'], ['Houlihan Lawrence', 'LIFESTYLE', '4.4', '33', '23M', '5,000+', 'Free', '0', 'Everyone', 'Lifestyle', 'October 12, 2017', '3.9.5', '4.2 and up'], ['Home Scouting® MLS Mobile', 'LIFESTYLE', '4.3', '1533', '7.7M', '100,000+', 'Free', '0', 'Everyone', 'Lifestyle', 'September 27, 2016', '2.2.6', '2.2 and up'], ['Housing-Real Estate & Property', 'LIFESTYLE', '4.1', '28301', 'Varies with device', '1,000,000+', 'Free', '0', 'Everyone', 'Lifestyle', 'July 13, 2018', '12.1.0', '4.1 and up'], ['ZipRealty Real Estate & Homes', 'LIFESTYLE', '4.0', '3937', '15M', '100,000+', 'Free', '0', 'Everyone', 'Lifestyle', 'July 27, 2018', '8.3.3', '4.4 and up']]
#
#
# Number of free apps in Google Play Store:  8891

# %%
# The element that indicates whether an app is free or not is element #4 in the appgle_data; and, the value
# of '0.0' indicates this.
a_free = []
for row in apple_data:
    if row[4] == '0.0': a_free.append(row)

print(a_free[:5])
print(len(a_free))
# Out:
# [['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1'], ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1'], ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1'], ['420009108', 'Temple Run', '65921024', 'USD', '0.0', '1724546', '3842', '4.5', '4.0', '1.6.2', '9+', 'Games', '40', '5', '1', '1'], ['284035177', 'Pandora - Music & Radio', '130242560', 'USD', '0.0', '1126879', '3594', '4.0', '4.5', '8.4.1', '12+', 'Music', '37', '4', '1', '1']]
# 4056

# %% [markdown]
# ### Analysis

# %% [markdown]
# #### Validation Strategy:
# #### 1. Build a minimal Android version of the app, and add it to Google Play.
# #### 2. If the app has a good response from users, we develop it further.
# #### 3. If the app is profitable after six months, we build an iOS version of the app and add it to the App Store.

# %% [markdown]
# #### Because our apps generate revenue from the number of people that are using them, we are looking for the types of apps that are best able to attract the most users. Because our goal is release an app in both markets, we are looking for app profiles that are successful on both platforms. We begin by looking at frequency tables for app genres from each store to get an idea of the most common genres in each market.

# %%
print(google_head)
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']

# %%
print(apple_head)
# Out:
# ['id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']

# %% [markdown]
# #### Genre Frequency Tables

# %%
# freq_table()
# Function takes a dataset, an index to count data in, and it has a second index parameter set as
# by default to None; if b_index == None, it returns a list of data pertaining to the values in
# the a_index; this is a dictionary of frequencies followed by figure of the total count to be
# used in percentage calculations; If b_index != None, it returns a list containing a_table,
# a_total, b_table, b_total, ab_table, and ab_total
def freq_table(a_dataset, a_index, b_index=None):
    
    a_table = {}
    b_table = {}
    ab_table = {}

    # Count the occurrences
    for row in a_dataset:
        if row[a_index] in a_table: a_table[row[a_index]] += 1
        else: a_table[row[a_index]] = 1
        if b_index != None:    
            if row[b_index] in b_table: b_table[row[b_index]] += 1
            else: b_table[row[b_index]] = 1
            ab_combined = row[a_index] + ", " + row[b_index]
            if ab_combined in ab_table: ab_table[ab_combined] += 1
            else: ab_table[ab_combined] = 1
    
    # To store the sume of all occurrences
    a_sum = 0
    b_sum = 0
    ab_sum = 0
    
    # Sum values in a_table
    for key in a_table:
        a_sum += a_table[key]
    
    # If argument given for b_index, sum b and ab tables
    if b_index != None:
        for key in b_table:
            b_sum += b_table[key]
        for key in ab_table:
            ab_sum += ab_table[key]
    
    # Change values in a_table to frequencies
    for key in a_table:
        a_table[key] = (a_table[key] / a_sum) * 100
    
    # If value passed for b_index, change values in b and ab tables to freq's
    if b_index != None:
        for key in b_table:
            b_table[key] = (b_table[key] / b_sum) * 100
        for key in ab_table:
            ab_table[key] = (ab_table[key] / ab_sum) * 100
            
    # If b_index == None, return list of a data
    if b_index == None:
        a_list = [a_table]
        return a_list
    else:
        # If b_index != None, return all a, b, and ab data
        ab_list = [a_table, b_table, ab_table]
        return ab_list

# %%
def print_table(a_dataset, a_index, b_index=None):

    # Call freq_table() function w/ values passed; save output
    list_tables = freq_table(a_dataset, a_index, b_index)

    # Separate a_list just in case there are others
    a_list = list_tables[0]

    # Create list of tuples from dictionary
    a_freqs = []
    for key in a_list:
        tup = (a_list[key], key)
        a_freqs.append(tup)

    # Sort a_freqs
    a_freqs = sorted(a_freqs, reverse=True)

    # Print items in sorted a_list
    print("a_index Frequencies:")
    print(20 * "-", "\n")
    for item in a_freqs:
        print(item[1], " : ", item[0])
    print("\n")

    # Check to see if b_index value was passed; sort; print
    if len(list_tables) > 1:

        # Create lists to print freq's
        b_freqs = []
        ab_freqs = []

        # Append dictionary keys, vals to b_list
        b_list = list_tables[1]
        for key in b_list:
            tup = (b_list[key], key)
            b_freqs.append(tup)

        # Sort b_freqs
        b_freqs = sorted(b_freqs, reverse=True)

        # Print items in b_list
        print("b_index Frequencies:")
        print(20 * "-", "\n")
        for item in b_freqs:
            print(item[1], " : ", item[0])
        print("\n")

        # Append dictionary keys, vals to ab_list
        ab_list = list_tables[2]
        for key in ab_list:
            tup = (ab_list[key], key)
            ab_freqs.append(tup)

        # Sort ab_freqs
        ab_freqs = sorted(ab_freqs, reverse=True)

        # Print items in ab_list
        print("ab_index Frequencies:")
        print(21 * "-", "\n")
        for item in ab_freqs:
            print(item[1], " : ", item[0])

# %%
# Create frequency table for the genre for iOS apps
# Element #11 contains the prime genre
print_table(a_free, 11)
# Out:
# a_index Frequencies:
# --------------------
#
# Games  :  55.64595660749507
# Entertainment  :  8.234714003944774
# Photo & Video  :  4.117357001972387
# Social Networking  :  3.5256410256410255
# Education  :  3.2544378698224854
# Shopping  :  2.983234714003945
# Utilities  :  2.687376725838264
# Lifestyle  :  2.3175542406311638
# Finance  :  2.0710059171597637
# Sports  :  1.947731755424063
# Health & Fitness  :  1.8737672583826428
# Music  :  1.6518737672583828
# Book  :  1.6272189349112427
# Productivity  :  1.5285996055226825
# News  :  1.4299802761341223
# Travel  :  1.3806706114398422
# Food & Drink  :  1.0601577909270217
# Weather  :  0.7642998027613412
# Reference  :  0.4930966469428008
# Navigation  :  0.4930966469428008
# Business  :  0.4930966469428008
# Catalogs  :  0.22189349112426035
# Medical  :  0.19723865877712032

# %% [markdown]
# #### Among the free, English apps, 55.65 percent are games. The genre with the next highest frequency in the App Store is Entertainment with 8.24 percent. Third and fourth are Photo & Video and Social Networking with 4.12 and 3.53 percent, respectively. So, the overwhelming majority of apps are games. Clearly, the most popular apps are those used for entertainment.
#
# #### Among the least frequent apps in the App Store are those that are used for productivity. These include navigation, medical, news and books. The three least frequent apps are for business, catalogs, and medical. And, they comprise 0.49, 0.22

# %%
# Create frequency table for the number of installations per genre for Android apps
# Element #5 contains the number of installations
# Element #1 contains the Category which seems to be the same info contained in element #6
print_table(g_free, 1, 5)
# Out:
# a_index Frequencies:
# --------------------
#
# FAMILY  :  19.88527724665392
# GAME  :  11.910921156225395
# TOOLS  :  8.581711843437184
# PRODUCTIVITY  :  4.4314475312113375
# LIFESTYLE  :  4.060285682150489
# SPORTS  :  4.03779102463165
# MEDICAL  :  3.9590597233157125
# BUSINESS  :  3.767855134405579
# HEALTH_AND_FITNESS  :  3.655381846811382
# COMMUNICATION, 500,000,000+  :  0.05623664379709819
# COMMUNICATION, 50+  :  0.05623664379709819
# COMICS, 100,000+  :  0.05623664379709819
# BUSINESS, 1+  :  0.05623664379709819
# BOOKS_AND_REFERENCE, 100+  :  0.05623664379709819
# BEAUTY, 100+  :  0.05623664379709819
# AUTO_AND_VEHICLES, 100+  :  0.05623664379709819
# AUTO_AND_VEHICLES, 10+  :  0.05623664379709819
# VIDEO_PLAYERS, 500,000+  :  0.04498931503767855
# TOOLS, 5+  :  0.04498931503767855
# TOOLS, 1+  :  0.04498931503767855
# SPORTS, 100,000,000+  :  0.04498931503767855
# SOCIAL, 50+  :  0.04498931503767855
# SHOPPING, 50,000+  :  0.04498931503767855
# PRODUCTIVITY, 1,000,000,000+  :  0.04498931503767855
# PRODUCTIVITY, 1+  :  0.04498931503767855
# PHOTOGRAPHY, 5,000+  :  0.04498931503767855
# PHOTOGRAPHY, 1,000,000,000+  :  0.04498931503767855
# PARENTING, 50,000+  :  0.04498931503767855
# NEWS_AND_MAGAZINES, 500+  :  0.04498931503767855
# NEWS_AND_MAGAZINES, 1,000,000,000+  :  0.04498931503767855
# MEDICAL, 1+  :  0.04498931503767855
# MAPS_AND_NAVIGATION, 100,000,000+  :  0.04498931503767855
# MAPS_AND_NAVIGATION, 10+  :  0.04498931503767855
# LIFESTYLE, 1+  :  0.04498931503767855
# LIBRARIES_AND_DEMO, 10,000,000+  :  0.04498931503767855
# HOUSE_AND_HOME, 100+  :  0.04498931503767855
# FOOD_AND_DRINK, 50+  :  0.04498931503767855
# FOOD_AND_DRINK, 10+  :  0.04498931503767855
# DATING, 10,000,000+  :  0.04498931503767855
# COMMUNICATION, 50,000,000+  :  0.04498931503767855
# BUSINESS, 500,000+  :  0.04498931503767855
# BOOKS_AND_REFERENCE, 5+  :  0.04498931503767855
# BOOKS_AND_REFERENCE, 100,000,000+  :  0.04498931503767855
# BOOKS_AND_REFERENCE, 10+  :  0.04498931503767855
# AUTO_AND_VEHICLES, 10,000+  :  0.04498931503767855
# WEATHER, 10,000+  :  0.03374198627825891
# WEATHER, 1,000+  :  0.03374198627825891
# VIDEO_PLAYERS, 500,000,000+  :  0.03374198627825891
# VIDEO_PLAYERS, 1,000,000,000+  :  0.03374198627825891
# TRAVEL_AND_LOCAL, 5+  :  0.03374198627825891
# SPORTS, 1+  :  0.03374198627825891
# PERSONALIZATION, 50+  :  0.03374198627825891
# PERSONALIZATION, 1+  :  0.03374198627825891
# PARENTING, 500,000+  :  0.03374198627825891
# MEDICAL, 5,000,000+  :  0.03374198627825891
# MAPS_AND_NAVIGATION, 500,000+  :  0.03374198627825891
# LIBRARIES_AND_DEMO, 100+  :  0.03374198627825891
# FINANCE, 10+  :  0.03374198627825891
# FAMILY, 500,000,000+  :  0.03374198627825891
# EVENTS, 500+  :  0.03374198627825891
# EVENTS, 100+  :  0.03374198627825891
# EVENTS, 1,000+  :  0.03374198627825891
# DATING, 5,000+  :  0.03374198627825891
# COMICS, 5,000+  :  0.03374198627825891
# COMICS, 1,000,000+  :  0.03374198627825891
# AUTO_AND_VEHICLES, 500+  :  0.03374198627825891
# ART_AND_DESIGN, 5,000+  :  0.03374198627825891
# WEATHER, 10+  :  0.022494657518839275
# VIDEO_PLAYERS, 10+  :  0.022494657518839275
# TRAVEL_AND_LOCAL, 10+  :  0.022494657518839275
# TOOLS, 1,000,000,000+  :  0.022494657518839275
# SOCIAL, 5+  :  0.022494657518839275
# SOCIAL, 1+  :  0.022494657518839275
# PRODUCTIVITY, 5+  :  0.022494657518839275
# PHOTOGRAPHY, 50+  :  0.022494657518839275
# PARENTING, 5,000+  :  0.022494657518839275
# NEWS_AND_MAGAZINES, 5+  :  0.022494657518839275
# MAPS_AND_NAVIGATION, 500+  :  0.022494657518839275
# MAPS_AND_NAVIGATION, 50,000,000+  :  0.022494657518839275
# LIBRARIES_AND_DEMO, 5,000,000+  :  0.022494657518839275
# HOUSE_AND_HOME, 5,000+  :  0.022494657518839275
# HOUSE_AND_HOME, 1,000+  :  0.022494657518839275
# HEALTH_AND_FITNESS, 5+  :  0.022494657518839275
# HEALTH_AND_FITNESS, 1+  :  0.022494657518839275
# GAME, 5+  :  0.022494657518839275
# FOOD_AND_DRINK, 500+  :  0.022494657518839275
# FOOD_AND_DRINK, 5+  :  0.022494657518839275
# FOOD_AND_DRINK, 1,000+  :  0.022494657518839275
# FINANCE, 100,000,000+  :  0.022494657518839275
# FINANCE, 1+  :  0.022494657518839275
# EVENTS, 5,000+  :  0.022494657518839275
# DATING, 100,000+  :  0.022494657518839275
# COMMUNICATION, 5+  :  0.022494657518839275
# COMICS, 500,000+  :  0.022494657518839275
# COMICS, 50,000+  :  0.022494657518839275
# COMICS, 10,000+  :  0.022494657518839275
# BUSINESS, 50,000,000+  :  0.022494657518839275
# BUSINESS, 5,000,000+  :  0.022494657518839275
# BUSINESS, 10,000,000+  :  0.022494657518839275
# BOOKS_AND_REFERENCE, 50+  :  0.022494657518839275
# AUTO_AND_VEHICLES, 5,000+  :  0.022494657518839275
# AUTO_AND_VEHICLES, 5+  :  0.022494657518839275
# AUTO_AND_VEHICLES, 100,000+  :  0.022494657518839275
# ART_AND_DESIGN, 50,000+  :  0.022494657518839275
# ART_AND_DESIGN, 100,000+  :  0.022494657518839275
# ART_AND_DESIGN, 1,000+  :  0.022494657518839275
# WEATHER, 500+  :  0.011247328759419637
# WEATHER, 50,000+  :  0.011247328759419637
# WEATHER, 5,000+  :  0.011247328759419637
# TRAVEL_AND_LOCAL, 50+  :  0.011247328759419637
# TRAVEL_AND_LOCAL, 1+  :  0.011247328759419637
# SOCIAL, 0+  :  0.011247328759419637
# SHOPPING, 5+  :  0.011247328759419637
# PHOTOGRAPHY, 5+  :  0.011247328759419637
# PHOTOGRAPHY, 10+  :  0.011247328759419637
# PERSONALIZATION, 5+  :  0.011247328759419637
# PARENTING, 5,000,000+  :  0.011247328759419637
# PARENTING, 10,000,000+  :  0.011247328759419637
# PARENTING, 10+  :  0.011247328759419637
# PARENTING, 1,000+  :  0.011247328759419637
# NEWS_AND_MAGAZINES, 50,000,000+  :  0.011247328759419637
# NEWS_AND_MAGAZINES, 0+  :  0.011247328759419637
# MAPS_AND_NAVIGATION, 50+  :  0.011247328759419637
# LIFESTYLE, 50,000,000+  :  0.011247328759419637
# LIFESTYLE, 5+  :  0.011247328759419637
# LIFESTYLE, 100,000,000+  :  0.011247328759419637
# LIBRARIES_AND_DEMO, 500+  :  0.011247328759419637
# LIBRARIES_AND_DEMO, 10+  :  0.011247328759419637
# HOUSE_AND_HOME, 50+  :  0.011247328759419637
# HOUSE_AND_HOME, 10+  :  0.011247328759419637
# HOUSE_AND_HOME, 1+  :  0.011247328759419637
# HEALTH_AND_FITNESS, 500,000,000+  :  0.011247328759419637
# HEALTH_AND_FITNESS, 100,000,000+  :  0.011247328759419637
# FOOD_AND_DRINK, 5,000+  :  0.011247328759419637
# FOOD_AND_DRINK, 1+  :  0.011247328759419637
# FINANCE, 50,000,000+  :  0.011247328759419637
# FAMILY, 1,000,000,000+  :  0.011247328759419637
# EVENTS, 10,000+  :  0.011247328759419637
# DATING, 10,000+  :  0.011247328759419637
# COMMUNICATION, 1+  :  0.011247328759419637
# COMICS, 50+  :  0.011247328759419637
# COMICS, 5,000,000+  :  0.011247328759419637
# COMICS, 100+  :  0.011247328759419637
# COMICS, 10,000,000+  :  0.011247328759419637
# BUSINESS, 100,000,000+  :  0.011247328759419637
# BUSINESS, 0+  :  0.011247328759419637
# BEAUTY, 500+  :  0.011247328759419637
# BEAUTY, 50+  :  0.011247328759419637
# BEAUTY, 5,000,000+  :  0.011247328759419637
# BEAUTY, 5,000+  :  0.011247328759419637
# BEAUTY, 100,000+  :  0.011247328759419637
# BEAUTY, 10,000+  :  0.011247328759419637
# BEAUTY, 1,000+  :  0.011247328759419637
# AUTO_AND_VEHICLES, 10,000,000+  :  0.011247328759419637
# AUTO_AND_VEHICLES, 1+  :  0.011247328759419637
# ART_AND_DESIGN, 100+  :  0.011247328759419637
# ART_AND_DESIGN, 10,000,000+  :  0.011247328759419637
# ART_AND_DESIGN, 10,000+  :  0.011247328759419637
# ART_AND_DESIGN, 0+  :  0.011247328759419637

# %% [markdown]
# #### Games dominate the Play Store, as well at 55.65 percent of the market. Entertainment and Photo & Video apps are the next largest segments at 8.24 and 4.12 percent, respectively.
#
# #### We can see that the largest portion of apps in the Play Store are those which have been installed at least 1M times but less than 10M. These apps comprise 14.34 percent of the market. The next two largest installation segments are 10M+ and 100K+ which comprise 12.10 and 10.22 percent, respectively.
#
# #### For the Google Play Store, we have the number of installations included in the available data. Although it is imperfect in that it bins the values very broadly. For example, the bin that contains the most installations is 10M+ and the next smallest bin is 1M+. And, the third largest bin is 100K+. So, this data are discretized, and the bins not as narrow as they otherwise could be. However, it is still useful to look at app genres as they relate to this installation information. For example, we can see below that 3.01 percent of all of the apps in the Play Store are family apps that have been installed at least 1M times, but less than 10M times. This is the largest segment of these combined categories. Family apps that have been installed 100K+ times but less than 1M times comprise 2.56 percent of the Play Store. And, games that have been installed 10M+ times are 2.51 percent of the market. It is worth noting that of the 11 largest segments of genre and installation categories combined, 7 are family apps and 4 are game apps. And, they account for more than 20 percent of the apps in the Play Store.
